# %% [markdown]
# <a href="https://colab.research.google.com/github/Kmpillo/Class_Analitica/blob/main/002_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS SERIES & DATAFRAMES
#
# *   Modulos
# *   Carga de datos
# *   Resumen de los datos: dimensiones y estructuras
# *   Detección y tratamiento de valores ausentes
# *   Detección de valores atípicos
# *   Ordenar el dataframe
# *   filtrar por columna o fila
# *   Query con pandas
# *  Joins

# %% [markdown]
# ## Modulos
# modulos/paquetes/librerias

# %% [markdown]
# los 2 principales repositorios son pip y conda

# %%
# Solo se hace una vez
# Instalar paquetes #
# !pip install pyod
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyod: filename=pyod-2.0.3-py3-none-any.whl size=200466 sha256=16e63775e7235b0cb7b6f90c711f44309f95df7ce8ff6005d2e89c1974085128
#   Stored in directory: /root/.cache/pip/wheels/2d/60/5b/f74eccd2c9c892a2c298202ca510f10995f9940647fcc2d97f
# Successfully built pyod
# ...

# %% [markdown]
# **en Visual Studio Code, se debe abrir una terminal y usar este código py -m pip install pandas**

# %%
import pyod

# %% [markdown]
# **Como saber que tengo instalado?**

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.5.0
# aiohttp                            3.11.13
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.5
# ale-py                             0.10.2
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.3.3.0.34.45
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
import pandas as pd # traernos las funciones para importar y trabajar con tablas de datos
import numpy as np # traernos las funciones para trabajar con arreglos/matrices/vectores datos

# %% [markdown]
# ## Crear una serie

# %%
s = {'Jairo': 1020159, 'Felipe': 1020486, 'Omar': 1020754} # crear un diccionario
ds_000 = pd.Series(s) # crear una serie de pandas usando el diccionario
ds_000 # ver serie de pandas
# Out:
# Jairo     1020159
# Felipe    1020486
# Omar      1020754
# dtype: int64

# %%
s = [1020159, 1020486, 1020754] # creamos un listado con la serie de informacion
list_indx = ['Jairo', 'Felipe', 'Omar'] # creamos un listado con los indices o nombres de las columnas
ds_000 = pd.Series(s,index = list_indx)# usamos la funcion pd.series para obtener una serie de pandas
ds_000
# Out:
# Jairo     1020159
# Felipe    1020486
# Omar      1020754
# dtype: int64

# %%
pd.Series()

# %% [markdown]
# ## Crear un dataframe
#
# * no hay dos columnas con el mismo nombre
# * FORMATO : una misma columna no puede mas de un tipo de dato (o solamente numerica o solamente texto, o solamente otro tipo)

# %%
# crear un diccionario
dm_000 = {
    'Job Title': ['Android Developer', 'Full Stack Web Developer', 'Full Stack Web Developer'],
    'Salary': [3456, 6789, 12345]
    }
df_000 = pd.DataFrame(data=dm_000) # construir un dataframe a partir de un diccionario (las llaves las va a utilizar para generar columnas)
df_000
# Out:
#                   Job Title  Salary
# 0         Android Developer    3456
# 1  Full Stack Web Developer    6789
# 2  Full Stack Web Developer   12345

# %%
s = [1020159, 1020486, 1020754] # lista de informacion con el salario
list_indx = ['Jairo', 'Felipe', 'Omar'] # lista con el trabajador
ds_000 = pd.Series(s,index = list_indx) # crear una serie de pandas con la lista de informacion y de indices
# crear un diccionario utilizando la serie de pandas generada anteriormente
dm_000 = {'Job Title': ['Android Developer', 'Full Stack Web Developer', 'Full Stack Web Developer'], 'Salary': ds_000}
df_000 = pd.DataFrame(data=dm_000) # crear el datfarame a partir de la serie de pandas
df_000
# Out:
#                        Job Title   Salary
# Jairo          Android Developer  1020159
# Felipe  Full Stack Web Developer  1020486
# Omar    Full Stack Web Developer  1020754

# %%
# crear una matriz o arreglo de datos usando numpy
da_000 = np.array(
    [
        ['Jairo', 'Android Developer', 1020159],
        ['Felipe', 'Full Stack Web Developer', 1020486],
        ['Omar', 'Full Stack Web Developer', 1020754]
        ]
        )
df_000 = pd.DataFrame(da_000,columns=['Name', 'Job Title', 'Salary']) # usar el arrglo de numpy e indicar explicitamente el nopmbre las columnas
df_000
# Out:
#      Name                 Job Title   Salary
# 0   Jairo         Android Developer  1020159
# 1  Felipe  Full Stack Web Developer  1020486
# 2    Omar  Full Stack Web Developer  1020754

# %%
df_000 = pd.DataFrame()
df_000
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# ### Carga de un archivo plano

# %%
# Ver la ayuda de la libreria (Metodos de lectura)
pd.read_csv?
# Out:
# Object `pd.read_csv` not found.

# %%
import pandas as pd # This line imports the pandas library and assigns it to the alias 'pd'
pd.read_csv('diabetes.csv') # Now you can use 'pd' to access pandas functions
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
#df = pd.read_csv("diabetes.csv", skiprows=5, usecols="A:I")
#Skiprow muestra cantidad de filas y usecols muestra cantidad de celdas

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
# @title Pregnancies vs Glucose

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Pregnancies', y='Glucose', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd

# %%
# CONSTRUIR LA DIRECCION DE UBICACION UN ARCHIVO
fullpath = "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.csv" # direccion o ruta de ubicacion del archivo

# %%
 # utilizar la funcion de lectura de "archivos planos" de pandas para leer archivo ubicado en la ruta
df_000 = pd.read_csv('https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.csv') # lea archivo en ruta ( .txt , .csv y .tsv)
df_000 # muestreme que hay en la variable
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# @title Salaries Reported

from matplotlib import pyplot as plt
df_000['Salaries Reported'].plot(kind='line', figsize=(8, 4), title='Salaries Reported')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_001 = pd.read_csv(fullpath, sep=",") # parametrizar la lectura del archivo
df_001
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# @title Rating vs Salary

from matplotlib import pyplot as plt
df_001.plot(kind='scatter', x='Rating', y='Salary', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_001 = pd.read_csv(fullpath, sep=",", header ='infer') # parametrizar la lectura del archivo
df_001
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# @title Employment Status

from matplotlib import pyplot as plt
import seaborn as sns
df_001.groupby('Employment Status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
list_colnames = ['A', 'B', 'C', 'D', 'E', 'F', 'G','H']
df_002 = pd.read_csv(fullpath, sep=",", names = list_colnames) # leer el archivo indicando el nombre de las columnas
df_002
# Out:
#             A                                 B                         C  \
# 0      Rating                      Company Name                 Job Title
# 1         3.8                            Sasken         Android Developer
# 2         4.5  Advanced Millennium Technologies         Android Developer
# 3         4.0                         Unacademy         Android Developer
# 4         3.8                SnapBizz Cloudtech         Android Developer
# ...       ...                               ...                       ...
# 22766     4.7                  Expert Solutions             Web Developer
# 22767     4.0           Nextgen Innovation Labs             Web Developer
# 22768     4.1                           Fresher  Full Stack Web Developer
# 22769     4.1                         Accenture  Full Stack Web Developer
# 22770     3.8                   Thomson Reuters   Associate Web Developer
#
#              D                  E          F                  G          H
# ...

# %%
# @title G

from matplotlib import pyplot as plt
import seaborn as sns
df_002.groupby('G').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
list_colnames = ['A', 'B', 'C', 'D', 'E', 'F', 'G','H']
df_003 = pd.read_csv(fullpath, sep=",", names = list_colnames, skiprows = 1) # salte la la primer fila en la lectura
df_003
# Out:
#          A                                 B                         C  \
# 0      3.8                            Sasken         Android Developer
# 1      4.5  Advanced Millennium Technologies         Android Developer
# 2      4.0                         Unacademy         Android Developer
# 3      3.8                SnapBizz Cloudtech         Android Developer
# 4      4.4            Appoids Tech Solutions         Android Developer
# ...    ...                               ...                       ...
# 22765  4.7                  Expert Solutions             Web Developer
# 22766  4.0           Nextgen Innovation Labs             Web Developer
# 22767  4.1                           Fresher  Full Stack Web Developer
# 22768  4.1                         Accenture  Full Stack Web Developer
# 22769  3.8                   Thomson Reuters   Associate Web Developer
#
#              D   E          F          G        H
# 0       400000   3  Bangalore  Full Time  Android
# ...

# %%
# @title G vs A

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_003['G'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_003, x='A', y='G', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-29-1a02cdc2006d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_003, x='A', y='G', inner='box', palette='Dark2')

# %% [markdown]
# ### Carga de un archivo de excel

# %%
# construir ruta de ubicacion del archivo
fullpath = "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.xlsx"

# %%
df_004 = pd.read_excel(fullpath) # usar la funcion de lectura de excel para pandas
df_004
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# @title Employment Status vs Salaries Reported

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_004['Employment Status'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_004, x='Salaries Reported', y='Employment Status', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-28-2f2c77db895c>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_004, x='Salaries Reported', y='Employment Status', inner='box', palette='Dark2')

# %% [markdown]
# ## Carga masiva de archivos

# %%
# lista de adirecciones donde estan ubicados cada uno de los archivo
list_filename = [
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt1.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt2.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt3.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt1.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt1.xlsx"
    ]

list_df = [] # lista vacia
#estructura de control for
for file_i in list_filename:
  list_df.append(pd.read_excel(file_i)) # la lista vacia se va a llenar de cada uno de los dataframes que va a leer
list_df # ver contenido de la lista
# Out:
# [      Rating                      Company Name          Job Title   Salary  \
#  0        3.8                            Sasken  Android Developer   400000
#  1        4.5  Advanced Millennium Technologies  Android Developer   400000
#  2        4.0                         Unacademy  Android Developer  1000000
#  3        3.8                SnapBizz Cloudtech  Android Developer   300000
#  4        4.4            Appoids Tech Solutions  Android Developer   600000
#  ...      ...                               ...                ...      ...
#  3408     4.0                  Fresherworld.com    Backend Process   180000
#  3409     3.8                       NCC Limited    Backend Process   300000
#  3410     4.5                             Groww    Backend Process   120000
#  3411     4.0                              Vogo    Backend Process   216000
#  3412     3.6                              FHPL    Backend Process   200000
#
# ...

# %%
df_01 = pd.concat(list_df) #unificar tablas de diferentes archivos (pegar varios en uno solo)
df_01
# Out:
#       Rating                      Company Name          Job Title   Salary  \
# 0        3.8                            Sasken  Android Developer   400000
# 1        4.5  Advanced Millennium Technologies  Android Developer   400000
# 2        4.0                         Unacademy  Android Developer  1000000
# 3        3.8                SnapBizz Cloudtech  Android Developer   300000
# 4        4.4            Appoids Tech Solutions  Android Developer   600000
# ...      ...                               ...                ...      ...
# 3408     4.0                  Fresherworld.com    Backend Process   180000
# 3409     3.8                       NCC Limited    Backend Process   300000
# 3410     4.5                             Groww    Backend Process   120000
# 3411     4.0                              Vogo    Backend Process   216000
# 3412     3.6                              FHPL    Backend Process   200000
#
#       Salaries Reported   Location Employment Status Job Roles
# ...

# %% [markdown]
# ![picture](https://raw.githubusercontent.com/elprincipitogauss/lesson/main/bindrows.png)

# %%
# enlistamos las direcciones a consultar con los exceles
list_filename = [
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt1.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt2.xlsx",
    "https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features_pt3.xlsx"
    ]
# recorrer la lista para leer cada uno de los exceles
for file_i in list_filename:
  df_a = pd.read_excel(file_i) # generar un dataframe leyendo la direccion en el iterando
  try: # intente realizar ...
    df_cont = pd.concat([df_cont,df_a]) # pegar por abajo la nueva base leida a la base inicial
  except:
    df_cont = df_a # el dataframe leido va a ser el datframe inicial del contenedor

df_cont
# Out:
#       Rating                      Company Name                 Job Title  \
# 0        3.8                            Sasken         Android Developer
# 1        4.5  Advanced Millennium Technologies         Android Developer
# 2        4.0                         Unacademy         Android Developer
# 3        3.8                SnapBizz Cloudtech         Android Developer
# 4        4.4            Appoids Tech Solutions         Android Developer
# ...      ...                               ...                       ...
# 6241     4.7                  Expert Solutions             Web Developer
# 6242     4.0           Nextgen Innovation Labs             Web Developer
# 6243     4.1                           Fresher  Full Stack Web Developer
# 6244     4.1                         Accenture  Full Stack Web Developer
# 6245     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %% [markdown]
# ## Resumen de los datos: dimensiones y estructuras

# %%
df = pd.read_csv('https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.csv')
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.head(3) #  encabezado del dataframe (ver las primeras filas en este caso 3)
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android

# %%
df.tail(7) # la cola de la tabla(ver las primeras filas en este caso 7)
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22763     4.4           Unicon Systems             Web Developer  500000
# 22764     5.0                   BJSHub             Web Developer  400000
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22763                  1  Bangalore         Full Time       Web
# 22764                  1  Bangalore         Full Time       Web
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# ...

# %%
df.sample(10) #ver una muestra aleatoria
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 774             3      150             76              0        0  21.0
# 1943            2      107             74             30      100  33.6
# 558            11      103             68             40        0  46.2
# 534             1       77             56             30       56  33.3
# 1978            1      109             56             21      135  25.2
# 1656            9       72             78             25        0  31.6
# 1001            1       88             78             29       76  32.0
# 50              1      103             80             11       82  19.4
# 151             4      114             65              0        0  21.9
# 69              4      146             85             27      100  28.9
#
#       DiabetesPedigreeFunction  Age  Outcome
# 774                      0.207   37        0
# 1943                     0.404   23        0
# ...

# %%
df.columns # el nombre de las columnas de la tabla
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
for columna in ['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
       'Location', 'Employment Status', 'Job Roles']:
    pass

# %%
df.shape # las dimensiones del dataframe (rows, columns)
# Out:
# (2000, 9)

# %%
df.shape[0] #Filas
# Out:
# 2000

# %%
df.shape[1] #columnas
# Out:
# 9

# %%
df.dtypes # tipo de datos en cada columna
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info() # resumen rapido de la informacion del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
df.sum(numeric_only=True) #suma
# Out:
# Pregnancies                   7407.00
# Glucose                     242365.00
# BloodPressure               138291.00
# SkinThickness                41870.00
# Insulin                     160508.00
# BMI                          64386.00
# DiabetesPedigreeFunction       941.86
# Age                          66181.00
# Outcome                        684.00
# dtype: float64

# %%
df.mean(numeric_only=True) #promedio
# Out:
# Pregnancies                   3.70350
# Glucose                     121.18250
# BloodPressure                69.14550
# SkinThickness                20.93500
# Insulin                      80.25400
# BMI                          32.19300
# DiabetesPedigreeFunction      0.47093
# Age                          33.09050
# Outcome                       0.34200
# dtype: float64

# %%
df.median(numeric_only=True) #mediana
# Out:
# Pregnancies                   3.000
# Glucose                     117.000
# BloodPressure                72.000
# SkinThickness                23.000
# Insulin                      40.000
# BMI                          32.300
# DiabetesPedigreeFunction      0.376
# Age                          29.000
# Outcome                       0.000
# dtype: float64

# %%
df.mode(numeric_only=True) #moda
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0     99.0           74.0            0.0      0.0  31.2
# 1          NaN      NaN            NaN            NaN      NaN  32.0
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.258  22.0      0.0
# 1                       NaN   NaN      NaN

# %%
df.std(numeric_only=True) #desviación estándar
# Out:
# Pregnancies                   3.306063
# Glucose                      32.068636
# BloodPressure                19.188315
# SkinThickness                16.103243
# Insulin                     111.180534
# BMI                           8.149901
# DiabetesPedigreeFunction      0.323553
# Age                          11.786423
# Outcome                       0.474498
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness               110.00
# Insulin                     744.00
# BMI                          80.60
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
df.quantile(0.99, numeric_only=True) # percentíl 99
# Out:
# Pregnancies                  13.00000
# Glucose                     195.00000
# BloodPressure               106.00000
# SkinThickness                52.00000
# Insulin                     495.00000
# BMI                          52.90000
# DiabetesPedigreeFunction      1.60098
# Age                          67.00000
# Outcome                       1.00000
# Name: 0.99, dtype: float64

# %%
df.quantile(0.75, numeric_only=True) # percentíl 75
# Out:
# Pregnancies                   6.000
# Glucose                     141.000
# BloodPressure                80.000
# SkinThickness                32.000
# Insulin                     130.000
# BMI                          36.800
# DiabetesPedigreeFunction      0.624
# Age                          40.000
# Outcome                       1.000
# Name: 0.75, dtype: float64

# %%
df.describe() # segun de el tipo de datos realizar un descriptivo rapido
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %% [markdown]
# **Cálculo estadístico ** Analisis descriptivo basico univariado

# %%
IQR = df["Rating"].quantile(0.75) -df["Rating"].quantile(0.25)
print(f'IQR:{IQR}')

Rango = df["Rating"].max() -df["Rating"].min()
print(f'Rango:{Rango}')

varianza = df["Rating"].var()
print(f'varianza:{varianza}')

moda = df["Rating"].mode()[0]
print(f'moda:{moda}')

coefvar = df['Rating'].std()/df['Rating'].mean()
print(f'coeficiente de variación: {coefvar}')
# Out:
# IQR:0.5
# Rango:4.0
# varianza:0.27007403205062036
# moda:4.0
# coeficiente de variación: 0.13263368007220205

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0        3.80                            Sasken         Android Developer
# 1        4.50  Advanced Millennium Technologies         Android Developer
# 2        4.00                         Unacademy         Android Developer
# 3        3.80                SnapBizz Cloudtech         Android Developer
# 4        4.40            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765    4.70                  Expert Solutions             Web Developer
# 22766    4.00           Nextgen Innovation Labs             Web Developer
# 22767    4.10                           Fresher  Full Stack Web Developer
# 22768    4.10                         Accenture  Full Stack Web Developer
# 22769    3.80                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.describe().to_excel('diabetes.csv'):

# %%
df ["Age"] # ver y/o seleccionar una sola columna
# Out:
# 0       47
# 1       23
# 2       31
# 3       24
# 4       21
#         ..
# 1995    33
# 1996    36
# 1997    42
# 1998    26
# 1999    25
# Name: Age, Length: 2000, dtype: int64

# %%
lista = ['Salary','Rating'] # ver y/o seleccionar varias columnas
df[lista]
# Out:
#         Salary  Rating
# 0       400000    3.80
# 1       400000    4.50
# 2      1000000    4.00
# 3       300000    3.80
# 4       600000    4.40
# ...        ...     ...
# 22765   200000    4.70
# 22766   300000    4.00
# 22767   192000    4.10
# 22768   300000    4.10
# 22769   300000    3.80
#
# [22770 rows x 2 columns]

# %%
df[['Salary', 'Salaries Reported', 'Rating']]
# Out:
#         Salary  Salaries Reported  Rating
# 0       400000                  3    3.80
# 1       400000                  3    4.50
# 2      1000000                  3    4.00
# 3       300000                  3    3.80
# 4       600000                  3    4.40
# ...        ...                ...     ...
# 22765   200000                  1    4.70
# 22766   300000                  1    4.00
# 22767   192000                 13    4.10
# 22768   300000                  7    4.10
# 22769   300000                  7    3.80
#
# [22770 rows x 3 columns]

# %%
df["fecha"] = pd.to_datetime(df["fecha"]) # en casos que las fechas esten en texto y que se quieran calcular la edad o sumar dias es necesario pasar a
# formato fecha  (Corregir el formato de fechas9)

# %% [markdown]
# Si queremos cambiar el tipo de dato dentro de las columnas hay que identificar el nombre  y tipo de la columna para ejecutar los siguinetes codigos

# %%
#df["Insulin"] = df["Insulin"].astype(int)

# %%
#df["Insulin"] = df["Insulin"].astype(str)

# %% [markdown]
# Si dentro de la información los números tienen  decimales o los numeros en formato con letras podemos ejecutar este codigo para cambiar el formato y ver los datos

# %%
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# ## Selección de elementos

# %%
# Seleccionar columnas
df.Rating
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22765    4.7
# 22766    4.0
# 22767    4.1
# 22768    4.1
# 22769    3.8
# Name: Rating, Length: 22770, dtype: float64

# %%
# Seleccionar columnas
df['Salaries Reported']
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 22765     1
# 22766     1
# 22767    13
# 22768     7
# 22769     7
# Name: Salaries Reported, Length: 22770, dtype: int64

# %%
df[["Salary", 'Rating']]
# Out:
#         Salary  Rating
# 0       400000     3.8
# 1       400000     4.5
# 2      1000000     4.0
# 3       300000     3.8
# 4       600000     4.4
# ...        ...     ...
# 22765   200000     4.7
# 22766   300000     4.0
# 22767   192000     4.1
# 22768   300000     4.1
# 22769   300000     3.8
#
# [22770 rows x 2 columns]

# %%
df.head(5)
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0    3.80                            Sasken  Android Developer   400000
# 1    4.50  Advanced Millennium Technologies  Android Developer   400000
# 2    4.00                         Unacademy  Android Developer  1000000
# 3    3.80                SnapBizz Cloudtech  Android Developer   300000
# 4    4.40            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
# Acceder a los datos con coordenadas
df.iloc[1,5] #[fila, columna]
# Out:
# 'Bangalore'

# %%
df.iloc[0:5, 0:4] #[Inicio_fila:fin_fila, iniico_columan:fin_columna]
# Out:
#    Rating                      Company Name          Job Title   Salary
# 0    3.80                            Sasken  Android Developer   400000
# 1    4.50  Advanced Millennium Technologies  Android Developer   400000
# 2    4.00                         Unacademy  Android Developer  1000000
# 3    3.80                SnapBizz Cloudtech  Android Developer   300000
# 4    4.40            Appoids Tech Solutions  Android Developer   600000

# %%
df.iloc[0, 6]
# Out:
# 'Full Time'

# %%
df.iloc[0,0]
# Out:
# 3.8

# %%
df.iloc[200:400, 3:8]
# Out:
#       Salary  Salaries Reported   Location Employment Status Job Roles
# 200   216000                  1  Bangalore         Full Time   Android
# 201  1100000                  1  Bangalore         Full Time   Android
# 202   400000                  1  Bangalore         Full Time   Android
# 203   300000                  1  Bangalore         Full Time   Android
# 204   720000                  1  Bangalore         Full Time   Android
# ..       ...                ...        ...               ...       ...
# 395   500000                  1  Bangalore         Full Time   Android
# 396   264000                  1  Bangalore         Full Time   Android
# 397  1300000                  1  Bangalore         Full Time   Android
# 398   300000                  1  Bangalore         Full Time   Android
# 399   500000                  1  Bangalore         Full Time   Android
#
# [200 rows x 5 columns]

# %%
df.iloc[:3, -2:]
# Out:
#   Employment Status Job Roles
# 0         Full Time   Android
# 1         Full Time   Android
# 2         Full Time   Android

# %%
df.loc[0:3, 'Job Roles']
# Out:
# 0    Android
# 1    Android
# 2    Android
# 3    Android
# Name: Job Roles, dtype: object

# %% [markdown]
# ## Filtros

# %%
# df[condición]

# %%
df.shape
# Out:
# (22770, 8)

# %%
df[df['Location']=='Bangalore'].mean(numeric_only=True)
# Out:
# Rating                    3.920223
# Salary               735344.739593
# Salaries Reported         2.314134
# dtype: float64

# %%
df[df['Location']=='New Delhi'].mean(numeric_only=True)
# Out:
# Rating                    3.943415
# Salary               658756.735632
# Salaries Reported         1.497126
# dtype: float64

# %%
df[df['Location']=='New Delhi']['Salary'].mean()
# Out:
# 658756.735632184

# %%
df[df['Job Roles']=='Android']
# Out:
#       Rating                      Company Name                 Job Title  \
# 0        3.8                            Sasken         Android Developer
# 1        4.5  Advanced Millennium Technologies         Android Developer
# 2        4.0                         Unacademy         Android Developer
# 3        3.8                SnapBizz Cloudtech         Android Developer
# 4        4.4            Appoids Tech Solutions         Android Developer
# ...      ...                               ...                       ...
# 2940     3.7                           Virtusa  Senior Android Developer
# 2941     3.6                 KPIT Technologies  Senior Android Developer
# 8529     4.0                                10   IOS & Android Developer
# 8779     4.2         Profcyma Career Solutions     Android/IOS Developer
# 8780     3.8                Raintree Computing     Android/IOS Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df[df['Rating']>4.5]
# Out:
#        Rating            Company Name                   Job Title  Salary  \
# 13        4.8            Retail Pulse  Android Developer - Intern   24000
# 27        4.9        Retranz Infolabs           Android Developer  500000
# 30        5.0           powerplay app  Android Developer - Intern  396000
# 32        4.6            Masai School           Android Developer  500000
# 35        5.0      Vispara Technosoft           Android Developer  200000
# ...       ...                     ...                         ...     ...
# 22742     5.0               Leanpitch               Web Developer  500000
# 22749     4.9  Web Developer For Hire      Web Developer - Intern  300000
# 22761     4.6            Masai School               Web Developer  101376
# 22764     5.0                  BJSHub               Web Developer  400000
# 22765     4.7        Expert Solutions               Web Developer  200000
#
#        Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# & == Y == AND AMBAS CONDICIONES SE CUMPLEN
# | == O == OR POR LO MENOS UNA CONDICIÓN SE CUMPLE

# %%
# Multiples condiciones
df[(df['Job Roles']=='Android')&(df['Salary']>600000)]# "Y" = "AND", indica que se deben cumplir ambas condiciones
# Out:
#       Rating       Company Name                 Job Title   Salary  \
# 2        4.0          Unacademy         Android Developer  1000000
# 12       3.7              Wibmo         Android Developer   900000
# 18       NaN        J.P. Morgan         Android Developer  1000000
# 22       4.0             Nuclei         Android Developer   800000
# 29       3.7           KrazyBee         Android Developer   708000
# ...      ...                ...                       ...      ...
# 2938     3.6      Tech Mahindra  Senior Android Developer   900000
# 2939     3.8                LTI  Senior Android Developer  1000000
# 2940     3.7            Virtusa  Senior Android Developer   800000
# 2941     3.6  KPIT Technologies  Senior Android Developer   700000
# 8529     4.0                 10   IOS & Android Developer   684000
#
#       Salaries Reported   Location Employment Status Job Roles
# 2                     3  Bangalore         Full Time   Android
# ...

# %%
# Multiples condiciones
df[(df['Job Roles']=='Android')|(df['Salary']>600000)]# "O" = "OR", indica que se debe cumplir por lo menos una de las condiciones
# Out:
#        Rating                                Company Name          Job Title  \
# 0         3.8                                      Sasken  Android Developer
# 1         4.5            Advanced Millennium Technologies  Android Developer
# 2         4.0                                   Unacademy  Android Developer
# 3         3.8                          SnapBizz Cloudtech  Android Developer
# 4         4.4                      Appoids Tech Solutions  Android Developer
# ...       ...                                         ...                ...
# 22707     4.6                 Regal Software Technologies      Web Developer
# 22724     3.8                                    Fortanix      Web Developer
# 22728     3.9                                      YMedia      Web Developer
# 22748     4.2  Full Time Soluções em Serviços Financeiros      Web Developer
# 22753     4.3                                      rtCamp      Web Developer
#
# ...

# %%
df[df['Job Roles']=='Android']['Salary'].mean()
# Out:
# 565911.0030560271

# %%
df[df['Job Roles']=='Android']['Salary'].describe()
# Out:
# count    2.945000e+03
# mean     5.659110e+05
# std      5.303402e+05
# min      1.200000e+04
# 25%      2.520000e+05
# 50%      4.000000e+05
# 75%      7.000000e+05
# max      7.100000e+06
# Name: Salary, dtype: float64

# %%
# Multiples condiciones
df[(df['Job Roles']=='Android')&(df['Salary']>600000)]['Rating']
# Out:
# 2       4.0
# 12      3.7
# 18      NaN
# 22      4.0
# 29      3.7
#        ...
# 2938    3.6
# 2939    3.8
# 2940    3.7
# 2941    3.6
# 8529    4.0
# Name: Rating, Length: 841, dtype: float64

# %%
df[(df['Job Roles']=='Android')&(df['Salary']>600000)]['Rating'].std()
# Out:
# 0.5204452092646539

# %%
df[(df['Job Roles']=='Android')&(df['Salary']>600000)]['Rating'].mean()
# Out:
# 3.9140476190476194

# %%
df[((df['Job Roles']=='Android')&(df['Salary']>600000))].shape[0]
# Out:
# 841

# %%
df[~((df['Job Roles']=='Android')&(df['Salary']>600000))].shape[0]
# Out:
# 21929

# %%
df.shape[0]
# Out:
# 22770

# %%
df[(df['Job Roles']=='Android')&(df['Salary']>600000)].shape[0]
# Out:
# 841

# %%
21929+841
# Out:
# 22770

# %%
df[df['Company Name']=='Sasken']['Salary'].mean()
# Out:
# 513333.3333333333

# %%
# prompt: calcula el salario promedio de los empleados de Sasken

df[df['Company Name'] == 'Sasken']['Salary'].mean()
# Out:
# 513333.3333333333

# %% [markdown]
# ## Identificación y tratamiento de valores ausentes

# %%
# Identificar los datos nulos
df.isnull()
# Out:
#        Rating  Company Name  Job Title  Salary  Salaries Reported  Location  \
# 0       False         False      False   False              False     False
# 1       False         False      False   False              False     False
# 2       False         False      False   False              False     False
# 3       False         False      False   False              False     False
# 4       False         False      False   False              False     False
# ...       ...           ...        ...     ...                ...       ...
# 22765   False         False      False   False              False     False
# 22766   False         False      False   False              False     False
# 22767   False         False      False   False              False     False
# 22768   False         False      False   False              False     False
# 22769   False         False      False   False              False     False
#
#        Employment Status  Job Roles
# ...

# %%
# Identificar los datos nulos
df.isna()
# Out:
#        Rating  Company Name  Job Title  Salary  Salaries Reported  Location  \
# 0       False         False      False   False              False     False
# 1       False         False      False   False              False     False
# 2       False         False      False   False              False     False
# 3       False         False      False   False              False     False
# 4       False         False      False   False              False     False
# ...       ...           ...        ...     ...                ...       ...
# 22765   False         False      False   False              False     False
# 22766   False         False      False   False              False     False
# 22767   False         False      False   False              False     False
# 22768   False         False      False   False              False     False
# 22769   False         False      False   False              False     False
#
#        Employment Status  Job Roles
# ...

# %%
df.isna().sum()
# Out:
# Rating               1
# Company Name         2
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
# Sumemos los datos nulos
df.isnull().sum()
# Out:
# Rating               1
# Company Name         2
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.shape[0]
# Out:
# 22770

# %%
# Veamos la proporción
df.isnull().sum()/df.shape[0]
# Out:
# Rating               0.000044
# Company Name         0.000088
# Job Title            0.000000
# Salary               0.000000
# Salaries Reported    0.000000
# Location             0.000000
# Employment Status    0.000000
# Job Roles            0.000000
# dtype: float64

# %%
# Veamos el dato en porcentaje
df.isnull().sum()/df.shape[0]*100
# Out:
# Rating               0.004392
# Company Name         0.008783
# Job Title            0.000000
# Salary               0.000000
# Salaries Reported    0.000000
# Location             0.000000
# Employment Status    0.000000
# Job Roles            0.000000
# dtype: float64

# %%
pd.concat([df.isnull().sum(), df.isnull().sum()/df.shape[0]*100], axis=1).rename(columns={0:'Ausentes', 1:'% Ausentes'})
# Out:
#                    Ausentes  % Ausentes
# Rating                    1    0.004392
# Company Name              2    0.008783
# Job Title                 0    0.000000
# Salary                    0    0.000000
# Salaries Reported         0    0.000000
# Location                  0    0.000000
# Employment Status         0    0.000000
# Job Roles                 0    0.000000

# %% [markdown]
# Las principales alternativas son:
# - **Eliminar los datos:** es buena idea cuando los ausentes son muy pocos registros `dropna()` o son un porcentaje muy alto y están concentrado en una sola columna `.drop(column=['Nombre'])`
# - **Imputar los datos:** Se debe considerar la distribución de los datos (simetricas y asimetricas) y el tipo de datos (series de tiempo)

# %% [markdown]
# ### Borrar valores ausentes

# %%
df.dropna()
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
print(df.shape)
df = df.dropna()
print(df.shape)
# Out:
# (22770, 8)
# (22767, 8)

# %%
# Eliminar filas que contengan datos nulos, aplica cuando la proporcion de nulos es pequeña < 5%
df.dropna(inplace=True)
# Out:
# <ipython-input-14-1e1a2265b08f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
#eliminar una columna que tenga un porcentaje alto de datos nulos >70%
df.drop(columns=['Rating'], inplace=True)
# Out:
# <ipython-input-15-970b8c3d3293>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Rating'], inplace=True)

# %%
df
# Out:
#                            Company Name                 Job Title   Salary  \
# 0                                Sasken         Android Developer   400000
# 1      Advanced Millennium Technologies         Android Developer   400000
# 2                             Unacademy         Android Developer  1000000
# 3                    SnapBizz Cloudtech         Android Developer   300000
# 4                Appoids Tech Solutions         Android Developer   600000
# ...                                 ...                       ...      ...
# 22765                  Expert Solutions             Web Developer   200000
# 22766           Nextgen Innovation Labs             Web Developer   300000
# 22767                           Fresher  Full Stack Web Developer   192000
# 22768                         Accenture  Full Stack Web Developer   300000
# 22769                   Thomson Reuters   Associate Web Developer   300000
#
#        Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.csv")
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.isnull().sum()
# Out:
# Rating               1
# Company Name         2
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %% [markdown]
# ### Imputar valores ausentes

# %%
df_imputed = df.copy()

# %%
df_imputed
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df_imputed.fillna(0) # llene todos los vacios con "ceros" numerico
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df_imputed.fillna('0')# llene todos los vacios con "ceros" en texto
# Out:
#       Rating                      Company Name                 Job Title  \
# 0        3.8                            Sasken         Android Developer
# 1        4.5  Advanced Millennium Technologies         Android Developer
# 2        4.0                         Unacademy         Android Developer
# 3        3.8                SnapBizz Cloudtech         Android Developer
# 4        4.4            Appoids Tech Solutions         Android Developer
# ...      ...                               ...                       ...
# 22765    4.7                  Expert Solutions             Web Developer
# 22766    4.0           Nextgen Innovation Labs             Web Developer
# 22767    4.1                           Fresher  Full Stack Web Developer
# 22768    4.1                         Accenture  Full Stack Web Developer
# 22769    3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df_imputed = df_imputed.fillna(0)

# %%
df_imputed.fillna(0, inplace=True)

# %%
df_imputed.isnull().sum()
# Out:
# Rating               0
# Company Name         2
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df_imputed['Rating'] = df_imputed['Rating'].fillna(0)
df_imputed['Company Name'] = df_imputed['Company Name'].fillna('Google')

# %%
df_imputed['Rating'].describe()
# Out:
# count    22769.000000
# mean         3.918209
# std          0.519686
# min          1.000000
# 25%          3.700000
# 50%          3.900000
# 75%          4.200000
# max          5.000000
# Name: Rating, dtype: float64

# %%
df_imputed['Rating'].hist()
# Out:
# <Axes: >

# %%
df_imputed['Rating'] = df_imputed['Rating'].fillna(df_imputed['Rating'].median())

# %%
# relleno segun contexto
df_imputed["X_2"] = df_imputed["Salary"].fillna(df["Salary"].mean())# imputar con un numero resultado de obtewner el promedio de la columna para todos los ausentes
df_imputed["X_2"] = df_imputed["Salary"].fillna(df["Salary"].median())
df_imputed["X_2"] = df_imputed["Salary"].fillna(df["Salary"].mode())
df_imputed.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles      X_2
# 0                  3  Bangalore         Full Time   Android   400000
# 1                  3  Bangalore         Full Time   Android   400000
# 2                  3  Bangalore         Full Time   Android  1000000
# 3                  3  Bangalore         Full Time   Android   300000
# 4                  3  Bangalore         Full Time   Android   600000

# %%
df_imputed['Rating'].mode()[0]
# Out:
# 4.0

# %%
df_imputed['Company Name'].value_counts()
# Out:
# Company Name
# Tata Consultancy Services         271
# Amazon                            184
# Infosys                           169
# Accenture                         150
# Cognizant Technology Solutions    144
#                                  ...
# Appoholics                          1
# Mobi App Solutions                  1
# Sports Flashes                      1
# Core Mobile                         1
# Nextgen Innovation Labs             1
# Name: count, Length: 11259, dtype: int64

# %%
df_imputed['Company Name'].fillna(df_imputed['Company Name'].mode()[0], inplace=True)
# Out:
# <ipython-input-36-e9fb5d22f81a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed['Company Name'].fillna(df_imputed['Company Name'].mode()[0], inplace=True)

# %%
df_imputed['Company Name'].mode()[0]

# %%
df_imputed.isnull().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# X_2                  0
# dtype: int64

# %% [markdown]
# ## Detectar Outliers o datos atipicos

# %%
Q3 = df['Salary'].quantile(0.75)
Q1 = df['Salary'].quantile(0.25)
Q2 = df['Salary'].median()

# %%
Q1
# Out:
# 300000.0

# %%
Q2
# Out:
# 500000.0

# %%
Q3
# Out:
# 900000.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 600000.0

# %%
Q3 + 1.5*IQR
# Out:
# 1800000.0

# %%
df['Salary'].hist(bins=100)
# Out:
# <Axes: >

# %%
df['Salary'].mean()
# Out:
# 695387.2112428634

# %%
Q2
# Out:
# 500000.0

# %%
# Valores atipicos superiores
df[df['Salary']>Q3 + 1.5*IQR]
# Out:
#        Rating                         Company Name  \
# 96        4.1                                Dunzo
# 106       4.0                  Walmart Global Tech
# 145       4.1                        First Student
# 161       4.4                            Microsoft
# 162       3.7                          Paytm Money
# ...       ...                                  ...
# 22241     3.9                      Western Digital
# 22271     4.1                    HealthGraph India
# 22274     2.9                          Sud Express
# 22366     4.2                              Greytip
# 22675     4.1  Chethan's Charters- GD FEA Employer
#
#                         Job Title   Salary  Salaries Reported   Location  \
# 96              Android Developer  2800000                  1  Bangalore
# 106             Android Developer  2300000                  1  Bangalore
# 145    Android Developer - Intern  2200000                  1  Bangalore
# ...

# %%
# OUTLIERS EXTREMOS SUPERIORES
df[df['Salary'] > Q3 + 3 * IQR]
# Out:
#        Rating          Company Name                 Job Title   Salary  \
# 96        4.1                 Dunzo         Android Developer  2800000
# 211       4.4       FP Tech Science         Android Developer  7100000
# 320       4.1   CONZUMEX INDUSTRIES         Android Developer  6900000
# 679       4.4             ShareChat  Senior Android Developer  3900000
# 734       4.0                 Borqs  Senior Android Developer  3600000
# ...       ...                   ...                       ...      ...
# 21130     4.3      Graduate Student             Test Engineer  3400000
# 22207     3.8  National Income Life             Web Developer  2900000
# 22225     4.0          PureSoftware             Web Developer  2800000
# 22271     4.1     HealthGraph India             Web Developer  4400000
# 22274     2.9           Sud Express             Web Developer  2900000
#
#        Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df[~(df['Salary']>Q3 + 1.5*IQR)]['Salary'].mean()
# Out:
# 584481.5715739798

# %%
df['Salary'].mode()
# Out:
# 0    300000
# Name: Salary, dtype: int64

# %%
Q2
# Out:
# 500000.0

# %%
df[df['Salary']<Q3 - 1.5*IQR] # IDENTIFICAR ATIPICOS INFERIORES CON EL IQR
# Out:
# Empty DataFrame
# Columns: [Rating, Company Name, Job Title, Salary, Salaries Reported, Location, Employment Status, Job Roles]
# Index: []

# %%
# Desviacion estandar
sigma = df.Salary.std()
sigma
# Out:
# 884399.0136761819

# %%
df[df['Salary']>df['Salary'].mean()+(2*sigma)]
# Out:
#        Rating            Company Name          Job Title   Salary  \
# 96        4.1                   Dunzo  Android Developer  2800000
# 211       4.4         FP Tech Science  Android Developer  7100000
# 314       4.3                 PhonePe  Android Developer  2500000
# 320       4.1     CONZUMEX INDUSTRIES  Android Developer  6900000
# 460       3.1  Bombinate Technologies  Android Developer  2500000
# ...       ...                     ...                ...      ...
# 21536     4.0                  Nuclei      Test Engineer  2600000
# 22207     3.8    National Income Life      Web Developer  2900000
# 22225     4.0            PureSoftware      Web Developer  2800000
# 22271     4.1       HealthGraph India      Web Developer  4400000
# 22274     2.9             Sud Express      Web Developer  2900000
#
#        Salaries Reported   Location Employment Status Job Roles
# 96                     1  Bangalore         Full Time   Android
# ...

# %%
df[df['Salary']>df['Salary'].mean()+(3*sigma)]
# Out:
#        Rating                Company Name                 Job Title   Salary  \
# 211       4.4             FP Tech Science         Android Developer  7100000
# 320       4.1         CONZUMEX INDUSTRIES         Android Developer  6900000
# 679       4.4                   ShareChat  Senior Android Developer  3900000
# 734       4.0                       Borqs  Senior Android Developer  3600000
# 744       4.0                      Meesho  Senior Android Developer  3700000
# ...       ...                         ...                       ...      ...
# 20040     3.8  Sheetal Kumar & Associates             Test Engineer  5200000
# 20066     3.9                   ACSESTECH             Test Engineer  4300000
# 20170     3.9                      KH TEC    Test Engineer - Intern  6600000
# 21130     4.3            Graduate Student             Test Engineer  3400000
# 22271     4.1           HealthGraph India             Web Developer  4400000
#
# ...

# %%
df[df['Salary']<df['Salary'].mean()-(2*sigma)]
# Out:
# Empty DataFrame
# Columns: [Rating, Company Name, Job Title, Salary, Salaries Reported, Location, Employment Status, Job Roles]
# Index: []

# %% [markdown]
# Tratamiento de outliers:
# - Si los outliers estan asociados a un error, se deben imputar, generalmente se consideran  las medidas de tendencia central
# - Si los outliers son de negocio se pueden dejar asi y usar modelos que no sean sensibles a outliers o imputarlos con el limite superior

# %%
# Imputar outliers
df['Salary_inliers'] = df['Salary'] # Creo otra columna con los mismos valores
df[["Salary", 'Salary_inliers']]
# Out:
#         Salary  Salary_inliers
# 0       400000          400000
# 1       400000          400000
# 2      1000000         1000000
# 3       300000          300000
# 4       600000          600000
# ...        ...             ...
# 22765   200000          200000
# 22766   300000          300000
# 22767   192000          192000
# 22768   300000          300000
# 22769   300000          300000
#
# [22770 rows x 2 columns]

# %%
df.loc[0, 'Salary']
# Out:
# 400000

# %%
df.loc[df['Salary']>df['Salary'].mean()+(2*sigma), 'Salary_inliers'] = df['Salary'].mean() # IMPUTANDO CON EL PROMEDIO
# Out:
# <ipython-input-69-542c7a80c3e6>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '695387.2112428634' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Salary']>df['Salary'].mean()+(2*sigma), 'Salary_inliers'] = df['Salary'].mean()

# %%
df.loc[
    df['Salary']>df['Salary'].mean()+(2*sigma),
       'Salary_inliers'] = df['Salary'].mean()+(2*sigma) # IMPUTAR CON EL MAXIMO ACEPTADO

# %%
df.boxplot('Salary_inliers')
# Out:
# <Axes: >

# %%
df.boxplot('Salary')
# Out:
# <Axes: >

# %% [markdown]
# ## Variables de texto

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df['Employment Status'].unique() # Muestra valores únicos
# Out:
# array(['Full Time', 'Intern', 'Contractor', 'Trainee'], dtype=object)

# %%
df['Employment Status'].nunique() # Muestra el número de valores únicos == "CARDINALIDAD"
# Out:
# 4

# %%
df['Employment Status'].value_counts() # Frecuencia Absoluta
# Out:
# Employment Status
# Full Time     20083
# Intern         2106
# Contractor      548
# Trainee          33
# Name: count, dtype: int64

# %%
df['Employment Status'].value_counts(normalize=True)*100 # Frecuencia Relativa
# Out:
# Employment Status
# Full Time     88.199385
# Intern         9.249012
# Contractor     2.406675
# Trainee        0.144928
# Name: proportion, dtype: float64

# %%
df['Job Roles'].value_counts()
# Out:
# Job Roles
# SDE         8183
# Android     2945
# Frontend    2163
# Java        1858
# Testing     1740
# IOS         1631
# Backend     1194
# Web          999
# Python       947
# Database     865
# Mobile       245
# Name: count, dtype: int64

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Software Development Engineer          2351
# Android Developer                      2029
# Software Development Engineer (SDE)    1614
# Front End Developer                    1412
# Test Engineer                          1314
#                                        ...
# Java Andriod Developer                    1
# Java Deceloper                            1
# Java/J2EE Programmer                      1
# Java SOA Developer                        1
# Associate Web Developer                   1
# Name: count, Length: 1080, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# Bangalore         8264
# Hyderabad         4467
# New Delhi         4176
# Chennai           2458
# Pune              2134
# Mumbai             749
# Kolkata            178
# Madhya Pradesh     155
# Kerala             108
# Jaipur              81
# Name: count, dtype: int64

# %%
df['Location'].value_counts(normalize=True)*100
# Out:
# Location
# Bangalore         36.293368
# Hyderabad         19.617918
# New Delhi         18.339921
# Chennai           10.794906
# Pune               9.371981
# Mumbai             3.289416
# Kolkata            0.781730
# Madhya Pradesh     0.680720
# Kerala             0.474308
# Jaipur             0.355731
# Name: proportion, dtype: float64

# %%
# alta cardinalidad
df['Company Name'].nunique()
# Out:
# 11259

# %%
# alta cardinalidad
df['Job Title'].nunique()
# Out:
# 1080

# %% [markdown]
# ## Ordenar el dataframe

# %%
df.sort_values(by=['Rating']) # ordenemelo utilizando la columna de forma ascendente == MENOR A MAYOR
# Out:
#        Rating                Company Name  \
# 11338     1.0  The Critical Slide Society
# 21832     1.0        Syflani Technologies
# 19976     1.0               Speck Systems
# 20039     1.0             YV Technologies
# 7692      1.0                    Ingresos
# ...       ...                         ...
# 5786      5.0               Kiran Robotix
# 6710      5.0     Ways & Works Consulting
# 278       5.0            Human Fractal.Ai
# 632       5.0                     Apps10X
# 18        NaN                 J.P. Morgan
#
#                                            Job Title   Salary  \
# 11338  Good Scope As A Python Developer - Contractor   500000
# 21832                                  Web Developer    72000
# 19976                                  Test Engineer   400000
# 20039                                  Test Engineer   300000
# 7692                                   IOS Developer   700000
# ...                                              ...      ...
# ...

# %%
df.sort_values(by=['Rating'], ascending=False) # ordenemelo utilizando la columna de forma no ascendente # MAYOR A MENOR
# Out:
#        Rating               Company Name                            Job Title  \
# 2281      5.0                   RA Music                    Android Developer
# 3918      5.0                   Easy Eat                    Backend Developer
# 18347     5.0        Shakla Technologies  Software Development Engineer (SDE)
# 11568     5.0  Tweak Talent Technologies                     Python Developer
# 3930      5.0            Mindful Machine                    Backend Developer
# ...       ...                        ...                                  ...
# 2823      1.0                     TellMe         Android Developer Contractor
# 7305      1.0                      Eye-D               IOS Developer - Intern
# 3969      1.0                    Jeebley                    Backend Developer
# 17968     1.0               Dangal Games      Software Development Engineer I
# 18        NaN                J.P. Morgan                    Android Developer
#
# ...

# %%
df.sort_values(by=['Rating','Salary'], ascending=False) # ordenar por varias columnas
# Out:
#        Rating            Company Name  \
# 15568     5.0  Gaana Lyrics Point.com
# 4658      5.0   Adwitech Info Systems
# 851       5.0                  Turnip
# 8519      5.0                  Loyakk
# 5773      5.0           AppsForBharat
# ...       ...                     ...
# 6328      1.0            SAMA Telecom
# 9978      1.0         IT Serve Global
# 21832     1.0    Syflani Technologies
# 5578      1.0               Numa Soft
# 18        NaN             J.P. Morgan
#
#                                             Job Title   Salary  \
# 15568          Software Development Engineer (SDE) II  9700000
# 4658   SQL Server Database Administrator - Contractor  7300000
# 851                             Sr. Android Developer  4200000
# 8519                                    IOS Team Lead  3600000
# 5773                                   Front End Lead  3300000
# ...                                               ...      ...
# ...

# %% [markdown]
# ## Filtrar por columna o fila

# %% [markdown]
# ### filtrar por columnas

# %%
df.filter(items=['Rating', 'Salary'], axis=1) # filtrar usando el axis 1 indica que los items filtrados columnas
# Out:
#        Rating   Salary
# 0         3.8   400000
# 1         4.5   400000
# 2         4.0  1000000
# 3         3.8   300000
# 4         4.4   600000
# ...       ...      ...
# 22765     4.7   200000
# 22766     4.0   300000
# 22767     4.1   192000
# 22768     4.1   300000
# 22769     3.8   300000
#
# [22770 rows x 2 columns]

# %%
df.filter(like='Job', axis=1) # seleccion columnas segun coincida con un patron
# Out:
#                       Job Title Job Roles
# 0             Android Developer   Android
# 1             Android Developer   Android
# 2             Android Developer   Android
# 3             Android Developer   Android
# 4             Android Developer   Android
# ...                         ...       ...
# 22765             Web Developer       Web
# 22766             Web Developer       Web
# 22767  Full Stack Web Developer       Web
# 22768  Full Stack Web Developer       Web
# 22769   Associate Web Developer       Web
#
# [22770 rows x 2 columns]

# %%
df.filter(like='e', axis=1) # seleccion columnas segun coincida con un patron
# Out:
#                            Company Name                 Job Title  \
# 0                                Sasken         Android Developer
# 1      Advanced Millennium Technologies         Android Developer
# 2                             Unacademy         Android Developer
# 3                    SnapBizz Cloudtech         Android Developer
# 4                Appoids Tech Solutions         Android Developer
# ...                                 ...                       ...
# 22765                  Expert Solutions             Web Developer
# 22766           Nextgen Innovation Labs             Web Developer
# 22767                           Fresher  Full Stack Web Developer
# 22768                         Accenture  Full Stack Web Developer
# 22769                   Thomson Reuters   Associate Web Developer
#
#        Salaries Reported Employment Status Job Roles
# 0                      3         Full Time   Android
# 1                      3         Full Time   Android
# ...

# %%
df.filter(regex='e$', axis=1) # seleccionar las que coincidancon un patron utilzando expresiones regulares
# las que terminen en 'e'
# Out:
#                            Company Name                 Job Title
# 0                                Sasken         Android Developer
# 1      Advanced Millennium Technologies         Android Developer
# 2                             Unacademy         Android Developer
# 3                    SnapBizz Cloudtech         Android Developer
# 4                Appoids Tech Solutions         Android Developer
# ...                                 ...                       ...
# 22765                  Expert Solutions             Web Developer
# 22766           Nextgen Innovation Labs             Web Developer
# 22767                           Fresher  Full Stack Web Developer
# 22768                         Accenture  Full Stack Web Developer
# 22769                   Thomson Reuters   Associate Web Developer
#
# [22770 rows x 2 columns]

# %% [markdown]
# ### Query con pandas

# %%
df.query('Salary > 400000 & Rating > 4') # realizar un query con condicion
# Out:
#        Rating                                Company Name  \
# 4         4.4                      Appoids Tech Solutions
# 20        4.1                                     Fresher
# 27        4.9                            Retranz Infolabs
# 31        4.2                                      Dcoder
# 32        4.6                                Masai School
# ...       ...                                         ...
# 22747     4.1                                    Flipkart
# 22748     4.2  Full Time Soluções em Serviços Financeiros
# 22753     4.3                                      rtCamp
# 22758     4.5                       Blu Ocean Innovations
# 22763     4.4                              Unicon Systems
#
#                     Job Title   Salary  Salaries Reported   Location  \
# 4           Android Developer   600000                  3  Bangalore
# 20          Android Developer   408000                  2  Bangalore
# ...

# %%
# hay dos formas de seleccionar o llamar una columna utilizando [] o utilizando el punto
df[df['Salaries Reported'] == df.Rating] # filtrar dataframe cuando cumple condicion
# Out:
#        Rating                                      Company Name  \
# 388       1.0                                 CEWIDUS Solutions
# 555       1.0                                Weinkling Autovity
# 899       1.0                                             Eye-D
# 1218      1.0                                             Lokas
# 1436      1.0                            Grey Line Technologies
# ...       ...                                               ...
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 21927     1.0                                   Corpyogi System
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                           Job Title  Salary  Salaries Reported   Location  \
# 388               Android Developer  120000                  1  Bangalore
# ...

# %%
# uso de comillas especiales para columnas que tienen nombres con espacios `nombre variable`
df.query('`Salaries Reported` == Rating') # obtener mismo resultado de consulta
# Out:
#        Rating                                      Company Name  \
# 388       1.0                                 CEWIDUS Solutions
# 555       1.0                                Weinkling Autovity
# 899       1.0                                             Eye-D
# 1218      1.0                                             Lokas
# 1436      1.0                            Grey Line Technologies
# ...       ...                                               ...
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 21927     1.0                                   Corpyogi System
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                           Job Title  Salary  Salaries Reported   Location  \
# 388               Android Developer  120000                  1  Bangalore
# ...

# %%
# puedo escribir "and" o "&"
# estrictamente ambas condiciones debe cumplir
df.query('(`Salaries Reported` == Rating) and (Salary > 200000)')
# Out:
#        Rating                                      Company Name  \
# 1218      1.0                                             Lokas
# 1443      1.0                                 Avantech Web Grid
# 1507      1.0                                  WinC IT Services
# 1804      1.0                                      NSP Security
# 1817      1.0                                   Anaadih Softech
# ...       ...                                               ...
# 20840     4.0                                               ABB
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                       Job Title  Salary  Salaries Reported   Location  \
# 1218      Android App Developer  204000                  1    Chennai
# ...

# %%
# puedo escribir "or" o "|"
# por lo menos alguna de las condiciones debe cumplir
df.query('(`Salaries Reported` == Rating) or (Salary > 600000)')
# Out:
#        Rating                                Company Name          Job Title  \
# 2         4.0                                   Unacademy  Android Developer
# 12        3.7                                       Wibmo  Android Developer
# 18        NaN                                 J.P. Morgan  Android Developer
# 22        4.0                                      Nuclei  Android Developer
# 29        3.7                                    KrazyBee  Android Developer
# ...       ...                                         ...                ...
# 22707     4.6                 Regal Software Technologies      Web Developer
# 22724     3.8                                    Fortanix      Web Developer
# 22728     3.9                                      YMedia      Web Developer
# 22748     4.2  Full Time Soluções em Serviços Financeiros      Web Developer
# 22753     4.3                                      rtCamp      Web Developer
#
# ...

# %%
# puedo escribir "not" o "!"
# niega el cumplimiento de condiciones
df.query('not ((`Salaries Reported` == Rating) or (Salary > 600000))')
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# 5         4.2                        Freelancer         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df[~((df['Salaries Reported'] == df['Rating'])|(df['Salary'] > 600000))]
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# 5         4.2                        Freelancer         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
# poder conjugar/encadenar/depender varias condiciones
# or |
# and &
# not ~
df.query('(`Salaries Reported` == Rating) or not (Salary > 100000)')
# Out:
#        Rating                     Company Name                   Job Title  \
# 5         4.2                       Freelancer           Android Developer
# 13        4.8                     Retail Pulse  Android Developer - Intern
# 24        4.3  Moveinsync Technology Solutions           Android Developer
# 48        3.4               Web Digital Mantra           Android Developer
# 51        3.7              FuGenX Technologies           Android Developer
# ...       ...                              ...                         ...
# 22731     3.0                        Agumentik               Web Developer
# 22745     4.2     TAS Information Intelligence               Web Developer
# 22755     3.1                          Foxmula      Web Developer - Intern
# 22760     4.0                      DiscoverWeb               Web Developer
# 22762     3.9                    Fresher Zones               Web Developer
#
# ...

# %%
df[df['Job Title'].str.contains('Android')]['Job Title'].value_counts()
# Out:
# Job Title
# Android Developer                              2029
# Senior Android Developer                        292
# Android Developer - Intern                      180
# Android Applications Developer                   63
# Android Software Engineer                        43
#                                                ...
# Game Developer ( Android, Windows)                1
# Android Testing                                   1
# Senior Software Engineer (Android/Mobility)       1
# Ace - Android Development                         1
# Android Framework Engineer                        1
# Name: count, Length: 92, dtype: int64

# %%
df[df['Job Title'].str.lower().str.contains('android')]['Job Title'].value_counts()
# Out:
# Job Title
# Android Developer                              2029
# Senior Android Developer                        292
# Android Developer - Intern                      180
# Android Applications Developer                   63
# Android Software Engineer                        43
#                                                ...
# Game Developer ( Android, Windows)                1
# Android Testing                                   1
# Senior Software Engineer (Android/Mobility)       1
# Ace - Android Development                         1
# Android Framework Engineer                        1
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# ## Uniones de datos "Joins"

# %% [markdown]
# ![picture](https://raw.githubusercontent.com/elprincipitogauss/lesson/main/img_joins.jpg)

# %%
# creo dos dataframes

df_izq = pd.DataFrame(
    np.array([['Jairo', 'AD', 120159], ['Felipe', 'FSWD', 444568], ['Marcela', 'UX', 215444], ['Omar', 'FSWD', 421554], ['Celia', 'ADP', 159445]]),
    columns=['Name', 'Job Title Code', 'Salary']
    )
df_der = pd.DataFrame(
    np.array([['AD', 'Android Developer', 'Part time'], ['FSWD', 'Full Stack Web Developer', 'Full time'], ['TE', 'Test Engineer', 'Full time'], ['ADP', 'Advanced Python Developer', 'Part time']]),
    columns=['Job Title Code', 'Job Title Description', 'work']
    )

# %%
df_izq

# %%
df_der

# %%
df = pd.merge(df_izq, df_der, how='outer', on='Job Title Code')
df

# %%
#  pd.merge para realizar join
# parametro how indica que tipo de join realizar
# parametro on indica las columnas que quiero utilizar de llaves para el cruce
df_joint_l = pd.merge(df_izq, df_der, how='left', on = 'Job Title Code')
# debo indicar los dataframes, el tipo de join en el HOW y la llave en ON
df_joint_l

# %%
df_joint_r = pd.merge(df_izq, df_der, how='right', on = 'Job Title Code')
df_joint_r

# %%
df_joint_i = pd.merge(df_izq, df_der, how='inner', on = 'Job Title Code')
df_joint_i

# %%
df_joint_o = pd.merge(df_izq, df_der, how='outer', on = 'Job Title Code')
df_joint_o

# %% [markdown]
# Para unir tablas que tienen la misma estructura sin considerar una **"LLAVE"**

# %%
filas = pd.concat([df_izq, df_izq, df_izq], axis=0) # en general se usa para pegar tablas iguales de distintos periodos
filas

# %%
columnas = pd.concat([df_izq, df_izq], axis=1) # no recomendado
columnas

# %% [markdown]
# ## Bibliografía

# %% [markdown]
# * (2022,Montenegro y Montenegro) Aprendizaje profundo. Diplomado de IA y AP.
# * BeginnersGuide. link :https://wiki.python.org/moin/BeginnersGuide/Programmers
# * Uniwebsidad. link :https://uniwebsidad.com/libros/algoritmos-python

# %%
df = pd.read_csv('https://raw.githubusercontent.com/elprincipitogauss/lesson/main/Salary_Dataset_with_Extra_Features.csv')
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rating               float64
# Company Name          object
# Job Title             object
# Salary                 int64
# Salaries Reported      int64
# Location              object
# Employment Status     object
# Job Roles             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rating               1
# Company Name         2
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22767.000000  2.276700e+04       22767.000000
# mean       3.918202  6.953711e+05           1.855800
# std        0.519709  8.844443e+05           6.824115
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df['Job Roles'].value_counts()
# Out:
# Job Roles
# SDE         8182
# Android     2943
# Frontend    2163
# Java        1858
# Testing     1740
# IOS         1631
# Backend     1194
# Web          999
# Python       947
# Database     865
# Mobile       245
# Name: count, dtype: int64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(8, 4)) # Creación del lienzo y los ejes

ax.hist(df['Salary'], bins=30) # Este hace el gráfico
# Barras = bar
# dispersión = scatter
# pastel = pie
# Barras horiziontales = barh
# caja y bigotes = boxplot

# Todos los aspectos de forma
ax.set_title('Histograma salarios')
ax.set_xlabel('$')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %%
import numpy as np
sns.set(style="ticks")
corr = df[['Rating',	'Salary', 'Salaries Reported']].corr().round(2)

mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(10, 8))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap,
            center=0, vmax=1, vmin=-1,
            square=True, linewidths=1, annot=True)
# https://seaborn.pydata.org/examples/many_pairwise_correlations.html
plt.show()

# %%
A = df['Job Roles'].value_counts().reset_index()
A
# Out:
#    Job Roles  count
# 0        SDE   8182
# 1    Android   2943
# 2   Frontend   2163
# 3       Java   1858
# 4    Testing   1740
# 5        IOS   1631
# 6    Backend   1194
# 7        Web    999
# 8     Python    947
# 9   Database    865
# 10    Mobile    245

# %%
import plotly.express as px

fig = px.bar(A, x='Job Roles', y='count')
fig.update_layout(
    title=dict(text="Cantidad por rol",font=dict(size=30))
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
